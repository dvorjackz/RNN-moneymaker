# %% [markdown]
# # RNN Moneymaker

# %%
import torch
import torch.optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import time
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
X_train, X_val, y_train, y_val, train_mean, val_mean, train_std, val_std = torch.load("assets/all.pt")

# %%
print("X_train shape: \t\t", X_train.shape)
print("X_val shape: \t\t", X_val.shape)
print("y_train shape: \t\t", y_train.shape)
print("y_val shape: \t\t", y_val.shape)
print("")

print("train_mean shape: \t", train_mean.shape)
print("val_mean: \t\t", val_mean.shape)
print("train_std: \t\t", train_std.shape)
print("val_std: \t\t", val_std.shape)
print("")
# Out:
# X_train shape: 		 torch.Size([2542795, 122, 3])
# X_val shape: 		 torch.Size([282732, 122, 3])
# y_train shape: 		 torch.Size([2542795, 1])
# y_val shape: 		 torch.Size([282732, 1])
#
# train_mean shape: 	 torch.Size([2542795, 3])
# val_mean: 		 torch.Size([282732, 3])
# train_std: 		 torch.Size([2542795, 3])
# val_std: 		 torch.Size([282732, 3])

# %%
# optimize for GPU if exists
if torch.cuda.is_available():
    X_train = X_train.cuda()
    y_train = y_train.cuda()
    X_val = X_val.cuda()
    y_val = y_val.cuda()

# %% [markdown]
# ### Training a RNN

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
batch_size = 32
dataset = Dataset(X_train, y_train)
loader = DataLoader(dataset, batch_size, shuffle=True)

# %%
class RNNClassifier(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(RNNClassifier, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        
        self.rnn = nn.LSTM(input_dim, hidden_dim, batch_first=True, num_layers=3)
        self.drop = nn.Dropout(0.5)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x, h=None):
        if type(h) == type(None):
            out, hn = self.rnn(x)
        else:
            out, hn = self.rnn(x, h.detach())
        out = self.drop(out)
        out = self.fc(out[:, -1, :])
        return out

# %%
input_dim = 3
hidden_dim = 20
output_dim = 1

# %%
model = RNNClassifier(input_dim, hidden_dim, output_dim)
if torch.cuda.is_available():
    model = model.to("cuda")
    
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_accs = []
val_accs = []
train_losses = []
val_losses = []
epoch = 0

# %% [markdown]
# ### Train the model

# %%
def pred_val(X_val, model):
    val_batch_size = 1000
    val_set_size = X_val.shape[0]
    preds = []
    with torch.no_grad():
        for i in range(0, val_set_size, val_batch_size):
            start = i
            end = min(i+val_batch_size, val_set_size)
            preds.append(model(X_val[start:end]))
    pred = torch.cat(preds, dim=0)
    return pred

# %%
t0 = time.time()
num_epochs = 3
for ep in range(num_epochs):
    tstart = time.time()
    for i, data in enumerate(loader):
        model.train()
        print("{}/{}".format(i, len(loader)), end='\r')
        optimizer.zero_grad()
        outputs = model(data[0])
        loss = criterion(outputs, data[1])
        loss.backward()
        optimizer.step()
    
        if i % 1000 == 0:
            with torch.no_grad():
                model.eval()
                train_losses.append(loss.item())
                pXval = pred_val(X_val, model)
                vloss = criterion(pXval, y_val)
                val_losses.append(vloss.item())
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,
                }, 'assets/partial_model.pt')

                print("training loss: {:<3.3f} \t val loss: {:<3.3f}".format(loss, vloss))

    with torch.no_grad():
        model.eval()
        pXval = model(X_val)
        vloss = criterion(pXval, y_val)
        val_losses.append(vloss.item()) 
        epoch += 1    
        tend = time.time()
        print('epoch: {:<3d} \t time: {:<3.2f} \t val loss: {:<3.3f}'.format(epoch, 
                tend - tstart, vloss.item()))
time_total = time.time() - t0
print('Total time: {:4.3f}, average time per epoch: {:4.3f}'.format(time_total, time_total / num_epochs))
# Out:
# training loss: 1.955 	 val loss: 2.011
# training loss: 1.499 	 val loss: 0.167
# training loss: 0.203 	 val loss: 0.148
# training loss: 0.206 	 val loss: 0.150
# training loss: 0.298 	 val loss: 0.149
# training loss: 0.279 	 val loss: 0.144
# training loss: 0.407 	 val loss: 0.143
# training loss: 0.194 	 val loss: 0.156
# training loss: 0.196 	 val loss: 0.155
# training loss: 0.118 	 val loss: 0.144
# training loss: 0.702 	 val loss: 0.155
# training loss: 0.203 	 val loss: 0.151
# training loss: 0.098 	 val loss: 0.147
# training loss: 0.191 	 val loss: 0.148
# training loss: 0.261 	 val loss: 0.167
# training loss: 0.252 	 val loss: 0.159
# training loss: 0.180 	 val loss: 0.160
# training loss: 0.304 	 val loss: 0.155
# training loss: 0.090 	 val loss: 0.148
# training loss: 0.123 	 val loss: 0.149
# training loss: 0.131 	 val loss: 0.158
# training loss: 0.206 	 val loss: 0.145
# training loss: 3.699 	 val loss: 0.146
# training loss: 0.271 	 val loss: 0.143
# training loss: 0.144 	 val loss: 0.144
# training loss: 0.254 	 val loss: 0.153
# training loss: 0.135 	 val loss: 0.145
# training loss: 0.283 	 val loss: 0.156
# training loss: 0.137 	 val loss: 0.150
# training loss: 0.223 	 val loss: 0.148
# training loss: 0.183 	 val loss: 0.146
# training loss: 0.146 	 val loss: 0.149
# training loss: 0.106 	 val loss: 0.145
# training loss: 0.236 	 val loss: 0.145
# training loss: 0.239 	 val loss: 0.148
# training loss: 0.105 	 val loss: 0.157
# training loss: 0.211 	 val loss: 0.152
# training loss: 0.226 	 val loss: 0.142
# training loss: 0.140 	 val loss: 0.145
# training loss: 0.125 	 val loss: 0.146
# training loss: 0.568 	 val loss: 0.146
# training loss: 0.523 	 val loss: 0.152
# training loss: 0.285 	 val loss: 0.144
# training loss: 0.261 	 val loss: 0.147
# training loss: 0.226 	 val loss: 0.156
# training loss: 0.143 	 val loss: 0.156
# training loss: 0.132 	 val loss: 0.146
# training loss: 0.402 	 val loss: 0.150
# training loss: 0.159 	 val loss: 0.143
# training loss: 0.140 	 val loss: 0.150
# training loss: 0.249 	 val loss: 0.145
# training loss: 0.343 	 val loss: 0.151
# training loss: 0.234 	 val loss: 0.152
# training loss: 0.093 	 val loss: 0.145
# training loss: 0.116 	 val loss: 0.143
# training loss: 0.273 	 val loss: 0.147
# training loss: 0.216 	 val loss: 0.146
# training loss: 0.275 	 val loss: 0.148
# training loss: 0.120 	 val loss: 0.149
# training loss: 0.253 	 val loss: 0.147
# training loss: 0.179 	 val loss: 0.147
# training loss: 0.203 	 val loss: 0.149
# training loss: 0.132 	 val loss: 0.143
# training loss: 0.207 	 val loss: 0.145
# training loss: 0.593 	 val loss: 0.149
# training loss: 0.131 	 val loss: 0.146
# training loss: 0.168 	 val loss: 0.156
# training loss: 0.144 	 val loss: 0.155
# training loss: 0.144 	 val loss: 0.156
# training loss: 0.162 	 val loss: 0.150
# training loss: 0.214 	 val loss: 0.148
# training loss: 0.088 	 val loss: 0.151
# training loss: 0.234 	 val loss: 0.154
# training loss: 0.849 	 val loss: 0.142
# training loss: 0.253 	 val loss: 0.146
# training loss: 0.153 	 val loss: 0.144
# training loss: 0.183 	 val loss: 0.154
# training loss: 0.145 	 val loss: 0.147
# training loss: 0.145 	 val loss: 0.144
# training loss: 0.132 	 val loss: 0.149
# epoch: 1   	 time: 1193.37 	 val loss: 0.146
# training loss: 0.088 	 val loss: 0.146
# training loss: 0.198 	 val loss: 0.148
# training loss: 0.208 	 val loss: 0.145
# training loss: 0.178 	 val loss: 0.143
# training loss: 0.105 	 val loss: 0.148
# training loss: 0.123 	 val loss: 0.148
# training loss: 0.144 	 val loss: 0.145
# training loss: 0.210 	 val loss: 0.156
# training loss: 0.115 	 val loss: 0.145
# training loss: 0.164 	 val loss: 0.144
# training loss: 0.156 	 val loss: 0.144
# training loss: 0.255 	 val loss: 0.142
# training loss: 1.258 	 val loss: 0.144
# training loss: 0.254 	 val loss: 0.142
# training loss: 0.119 	 val loss: 0.142
# training loss: 0.331 	 val loss: 0.144
# training loss: 0.075 	 val loss: 0.156
# training loss: 0.187 	 val loss: 0.150
# training loss: 0.159 	 val loss: 0.141
# training loss: 0.317 	 val loss: 0.146
# training loss: 0.112 	 val loss: 0.146
# training loss: 0.231 	 val loss: 0.149
# training loss: 0.247 	 val loss: 0.146
# training loss: 0.138 	 val loss: 0.146
# training loss: 0.216 	 val loss: 0.150
# training loss: 0.269 	 val loss: 0.145
# training loss: 0.193 	 val loss: 0.148
# training loss: 0.140 	 val loss: 0.161
# training loss: 0.099 	 val loss: 0.149
# training loss: 0.215 	 val loss: 0.146
# training loss: 0.252 	 val loss: 0.147
# training loss: 0.167 	 val loss: 0.144
# training loss: 0.163 	 val loss: 0.145
# training loss: 0.120 	 val loss: 0.142
# training loss: 0.125 	 val loss: 0.146
# training loss: 0.134 	 val loss: 0.146
# training loss: 0.121 	 val loss: 0.147
# training loss: 0.132 	 val loss: 0.145
# training loss: 0.190 	 val loss: 0.142
# training loss: 0.113 	 val loss: 0.145
# training loss: 0.129 	 val loss: 0.149
# training loss: 0.195 	 val loss: 0.148
# training loss: 0.327 	 val loss: 0.148
# training loss: 0.155 	 val loss: 0.146
# training loss: 0.676 	 val loss: 0.150
# training loss: 0.211 	 val loss: 0.152
# training loss: 0.178 	 val loss: 0.142
# training loss: 0.207 	 val loss: 0.146
# training loss: 0.215 	 val loss: 0.148
# training loss: 0.286 	 val loss: 0.147
# training loss: 0.233 	 val loss: 0.150
# training loss: 0.151 	 val loss: 0.141
# training loss: 0.154 	 val loss: 0.144
# training loss: 0.135 	 val loss: 0.154
# training loss: 0.189 	 val loss: 0.150
# training loss: 0.153 	 val loss: 0.156
# training loss: 0.101 	 val loss: 0.146
# training loss: 0.411 	 val loss: 0.142
# training loss: 0.212 	 val loss: 0.152
# training loss: 0.176 	 val loss: 0.142
# training loss: 0.091 	 val loss: 0.150
# training loss: 0.106 	 val loss: 0.145
# training loss: 0.157 	 val loss: 0.145
# training loss: 0.117 	 val loss: 0.144
# training loss: 0.278 	 val loss: 0.150
# training loss: 0.330 	 val loss: 0.145
# training loss: 0.965 	 val loss: 0.143
# training loss: 0.224 	 val loss: 0.147
# training loss: 0.156 	 val loss: 0.147
# training loss: 0.143 	 val loss: 0.146
# training loss: 0.207 	 val loss: 0.142
# training loss: 0.254 	 val loss: 0.142
# training loss: 0.175 	 val loss: 0.142
# training loss: 0.107 	 val loss: 0.145
# training loss: 0.382 	 val loss: 0.148
# training loss: 0.201 	 val loss: 0.150
# training loss: 0.212 	 val loss: 0.144
# training loss: 0.138 	 val loss: 0.145
# training loss: 0.155 	 val loss: 0.146
# training loss: 0.269 	 val loss: 0.145
# epoch: 2   	 time: 1191.13 	 val loss: 0.147
# training loss: 0.390 	 val loss: 0.148
# training loss: 0.100 	 val loss: 0.150
# training loss: 0.273 	 val loss: 0.143
# training loss: 0.050 	 val loss: 0.146
# training loss: 0.173 	 val loss: 0.145
# training loss: 0.212 	 val loss: 0.146
# training loss: 0.636 	 val loss: 0.142
# training loss: 0.229 	 val loss: 0.144
# training loss: 0.315 	 val loss: 0.150
# training loss: 0.295 	 val loss: 0.145
# training loss: 0.300 	 val loss: 0.148
# training loss: 0.308 	 val loss: 0.148
# training loss: 0.127 	 val loss: 0.148
# training loss: 0.100 	 val loss: 0.150
# training loss: 0.155 	 val loss: 0.142
# training loss: 0.459 	 val loss: 0.143
# training loss: 0.759 	 val loss: 0.144
# training loss: 0.329 	 val loss: 0.146
# training loss: 0.154 	 val loss: 0.151
# training loss: 0.312 	 val loss: 0.152
# training loss: 0.113 	 val loss: 0.142
# training loss: 0.178 	 val loss: 0.149
# training loss: 0.145 	 val loss: 0.146
# training loss: 0.143 	 val loss: 0.145
# training loss: 0.257 	 val loss: 0.142
# training loss: 0.189 	 val loss: 0.144
# training loss: 0.094 	 val loss: 0.141
# training loss: 0.168 	 val loss: 0.141
# training loss: 0.234 	 val loss: 0.143
# training loss: 0.261 	 val loss: 0.145
# training loss: 0.140 	 val loss: 0.150
# training loss: 0.180 	 val loss: 0.153
# training loss: 0.306 	 val loss: 0.157
# training loss: 0.130 	 val loss: 0.146
# training loss: 0.280 	 val loss: 0.144
# training loss: 0.155 	 val loss: 0.143
# training loss: 0.253 	 val loss: 0.141
# training loss: 0.187 	 val loss: 0.143
# training loss: 0.339 	 val loss: 0.148
# training loss: 0.109 	 val loss: 0.145
# training loss: 0.122 	 val loss: 0.145
# training loss: 0.184 	 val loss: 0.147
# training loss: 0.203 	 val loss: 0.149
# training loss: 0.176 	 val loss: 0.140
# training loss: 0.183 	 val loss: 0.143
# training loss: 0.140 	 val loss: 0.145
# training loss: 0.148 	 val loss: 0.143
# training loss: 0.218 	 val loss: 0.142
# training loss: 0.336 	 val loss: 0.150
# training loss: 0.356 	 val loss: 0.146
# training loss: 0.172 	 val loss: 0.142
# training loss: 0.179 	 val loss: 0.153
# training loss: 0.186 	 val loss: 0.151
# training loss: 0.379 	 val loss: 0.142
# training loss: 0.190 	 val loss: 0.151
# training loss: 0.157 	 val loss: 0.144
# training loss: 0.267 	 val loss: 0.143
# training loss: 0.064 	 val loss: 0.157
# training loss: 0.105 	 val loss: 0.145
# training loss: 0.059 	 val loss: 0.152
# training loss: 0.321 	 val loss: 0.149
# training loss: 0.249 	 val loss: 0.149
# training loss: 0.121 	 val loss: 0.143
# training loss: 0.204 	 val loss: 0.146
# training loss: 0.160 	 val loss: 0.144
# training loss: 0.119 	 val loss: 0.141
# training loss: 0.214 	 val loss: 0.142
# training loss: 0.126 	 val loss: 0.150
# training loss: 0.541 	 val loss: 0.147
# training loss: 0.082 	 val loss: 0.144
# training loss: 0.086 	 val loss: 0.145
# training loss: 0.282 	 val loss: 0.143
# training loss: 0.147 	 val loss: 0.142
# training loss: 0.779 	 val loss: 0.145
# training loss: 0.163 	 val loss: 0.141
# training loss: 0.217 	 val loss: 0.140
# training loss: 0.079 	 val loss: 0.144
# training loss: 0.096 	 val loss: 0.144
# training loss: 0.247 	 val loss: 0.140
# training loss: 0.202 	 val loss: 0.145
# epoch: 3   	 time: 1243.57 	 val loss: 0.142
# Total time: 3628.069, average time per epoch: 1209.356

# %% [markdown]
# ### Training loss vs. validation loss

# %%
t_losses = [i for i in train_losses if i < 4000]
plt.plot(t_losses)
plt.plot(val_losses)
plt.title('loss history')
plt.xlabel('thousand iterations')
plt.ylabel('loss')
plt.yscale('log')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
model.eval()

pred = pred_val(X_val, model)
val_loss = criterion(pred, y_val).item()

print("Final model evaluation: ", val_loss)
# Out:
# Final model evaluation:  0.14173883199691772

# %% [markdown]
# ### One-step lag predictor
# The one-step lag predictor simply outputs the last timestep in the input sequence. Our model should outperform the one-step lag predictor.

# %%
def one_step_lag_predictor(X):
    return X[:, -1, 0].unsqueeze(1)

p_val_naive = one_step_lag_predictor(X_val.cpu())
loss_naive = criterion(p_val_naive, y_val.cpu())

print("Loss from 1-step lag predictor:\t{}\nLoss from our model:\t\t{}".format(loss_naive, val_loss))
# Out:
# Loss from 1-step lag predictor:	0.14193207025527954
# Loss from our model:		0.14173883199691772

# %% [markdown]
# ### Standard deviation difference

# %%
# switch back to cpu for plotting
X_train = X_train.cpu()
y_train = y_train.cpu()
X_val = X_val.cpu()
y_val = y_val.cpu()
pred = pred.cpu()

# backprop components no longer needed
X_train = X_train.detach()
y_train = y_train.detach()
X_val = X_val.detach()
y_val = y_val.detach()
pred = pred.detach()

# %%
f1 = plt.figure()

ax1 = f1.add_subplot() 
ax1.plot((pred - y_val)[500:522])
ax1.set_title('price std diff')
ax1.set(xlabel='window', ylabel='std')

plt.show()

# plt.plot((pred[:,3] - y_val.cpu()[:,3]).detach())
# plt.title('std difference')
# plt.plot([1, 2, 3])

# %% [markdown]
# ### Actual price difference

# %%
# denormalize the data
pred_abs = pred * val_std[:,0].unsqueeze(1) + val_mean[:,0].unsqueeze(1)
y_val_abs = y_val.cpu() * val_std[:,0].unsqueeze(1) + val_mean[:,0].unsqueeze(1)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 10))

ax1.set_title("actual price difference")
ax1.plot((pred_abs - y_val_abs)[500:622])

ax2.set_title("actual price vs predicted price")
l1, = ax2.plot(pred_abs[500:622])
l1.set_label("predicted price")
l2, = ax2.plot(y_val_abs[500:622])
l2.set_label("actual price")

plt.legend()
plt.show()
